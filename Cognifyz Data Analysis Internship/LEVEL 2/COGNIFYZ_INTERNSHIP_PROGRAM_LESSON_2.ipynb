# %% [markdown]
# # COGNIFYZ INTERNSHIP PROGRAM LEVEL 2

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mitosheet as mt

# %%
# load dataset
df = pd.read_csv('Dataset.csv')
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City
# 0        6317637        Le Petit Souffle           162       Makati City  \
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address
# 0  Third Floor, Century City Mall, Kalayaan Avenu...  \
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality
# 0   Century City Mall, Poblacion, Makati City  \
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443  \
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
# list all columns in dataset
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# get information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# drop null records
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
# describe the dataset
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude
# count   9.542000e+03   9542.000000  9542.000000  9542.000000  \
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ### LEVEL 2
# #### Task 1: Restaurant Ratings
# ##### a. Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
# Plotting the histogram of the ratings
plt.hist(df['Aggregate rating'], bins=10, color='teal', edgecolor='black')
plt.title('Distribution of Aggregate Ratings')
plt.xlabel('Aggregate Ratings')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Define bins for ratings from 1 to 5
bins = [0, 1, 2, 3, 4, 5]
labels = ['0-1', '1-2', '2-3', '3-4', '4-5']
df_1 = df
df_1['Rating range'] = pd.cut(df_1['Aggregate rating'], bins=bins, labels=labels, include_lowest=True)

# Count ratings in each bin
rating_range_counts = df_1['Rating range'].value_counts()
print(rating_range_counts)

# visualize this information
rating_range_counts.plot(kind='bar', color='teal')
plt.title('Count of Ratings in Each Range')
plt.xlabel('Rating Range')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Rating range
# 3-4    4381
# 0-1    2148
# 2-3    1891
# 4-5    1112
# 1-2      10
# Name: count, dtype: int64

# %% [markdown]
# Therefore the most common rating range is "3-4"

# %% [markdown]
# ##### b. Calculate the average number of votes received by restaurants.

# %%
# average number of votes received by restaurants
average_votes = round(df_1['Votes'].mean(), 0)
print(f"The average number of votes received by restaurants is: {average_votes}")
# Out:
# The average number of votes received by restaurants is: 157.0

# %% [markdown]
# #### Task 2: Cuisine Combination
# ##### a. Identify the most common combinations of cuisines in the dataset.

# %%
# identity the most common combination of cuisines
most_common_cuisine_combo = df['Cuisines'].value_counts()
most_common_cuisine_combo
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# #### Task 3: Geographic Analysis
# ##### a. Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %%
# import libraries
import geopandas as gpd
import folium

# %%
# Create a GeoDataFrame from the DataFrame
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# Set the coordinate system to WGS84 (latitude/longitude)
gdf.set_crs(epsg=4326, inplace=True)

# Initialize the plot
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the basemap
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(ax=ax, color='lightgrey', edgecolor='black')

# Plot the restaurants
gdf.plot(ax=ax, markersize=10, color='blue', marker='o', label='Restaurants')

# Set plot title and labels
plt.title('Restaurant Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)

# Show the plot
plt.show()
# Out:
# C:\Users\JusticePC\AppData\Local\Temp\ipykernel_5156\1845617332.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# import KMeans from sklearn.cluster for the clusters
from sklearn.cluster import KMeans

# Extract latitude and longitude
X = df[['Latitude', 'Longitude']]

# Normalize the data
X = (X - X.mean()) / X.std()

# %%
# Number of clusters
k = 5

# K-means clustering
kmeans = KMeans(n_clusters=k, random_state=0)
df['Cluster'] = kmeans.fit_predict(X)

# Check the cluster centers
print(kmeans.cluster_centers_)
# Out:
# [[ 0.23835932  0.30522148]
#  [-2.55101962 -1.68026442]
#  [ 1.15435553 -3.46926454]
#  [-5.34048244  0.7646957 ]
#  [-1.18837878  0.47100594]]

# %%
# Create a GeoDataFrame from the DataFrame
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# Set the coordinate system to WGS84 (latitude/longitude)
gdf.set_crs(epsg=4326, inplace=True)

# Initialize the plot
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the basemap
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(ax=ax, color='lightgrey', edgecolor='black')

# Define color palette for clusters
colors = ['red', 'blue', 'green', 'purple', 'orange']

# Plot the clusters
for cluster, color in enumerate(colors):
    subset = gdf[gdf['Cluster'] == cluster]
    subset.plot(ax=ax, color=color, label=f'Cluster {cluster}', markersize=50, marker='o', legend=True)

# Set plot title and labels
plt.title('Restaurant Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)

# Show the plot
plt.show()
# Out:
# C:\Users\JusticePC\AppData\Local\Temp\ipykernel_5156\3076643099.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# Group data by cluster and count the number of restaurants in each cluster
cluster_summary = df.groupby('Cluster').size().reset_index(name='Count')
print(cluster_summary)
# Out:
#    Cluster  Count
# 0        0   8002
# 1        1    557
# 2        2    509
# 3        3    123
# 4        4    351

# %% [markdown]
# #### Task 4: Restaurant Chains
# ##### a. Identify if there are any restaurant chains present in the dataset.

# %%
# check the number of times each restaurants appeared in the dataset
name_count = df['Restaurant Name'].value_counts()

# check for restaurants that appeared more than once
restaurant_chain = name_count[name_count > 1]
print(restaurant_chain)
# Out:
# Restaurant Name
# Cafe Coffee Day                   83
# Domino's Pizza                    79
# Subway                            63
# Green Chick Chop                  51
# McDonald's                        48
#                                   ..
# Zaika Kathi Rolls                  2
# The Night Owl                      2
# The Cheesecake Factory             2
# New Kadimi                         2
# Ceviche Tapas Bar & Restaurant     2
# Name: count, Length: 734, dtype: int64

# %% [markdown]
# ##### b. Analyze the ratings and popularity of different restaurant chains.

# %%
# Turn the restaurant names that appeared more than once into a list called chains_list
chains_list = restaurant_chain.index.tolist()

# Initialize empty lists to store average ratings and popularity
avg_ratings = []
popularity = []

# Calculate average ratings and popularity for each chain
for chain in chains_list:
    chain_data = df[df['Restaurant Name'] == chain]
    avg_rating = chain_data['Aggregate rating'].mean()
    num_locations = len(chain_data)
    
    avg_ratings.append(avg_rating)
    popularity.append(num_locations)

# Create a DataFrame to store the results
chain_analysis = pd.DataFrame({
    'Chain': chains_list,
    'Average_Rating': avg_ratings,
    'Popularity': popularity
})

# Sort the DataFrame by AverageRating in descending order
chain_analysis = chain_analysis.sort_values(by='Average_Rating', ascending=False)

print(chain_analysis)
# Out:
#                          Chain  Average_Rating  Popularity
# 188           Talaga Sampireun           4.900           3
# 665           Silantro Fil-Mex           4.850           2
# 330    AB's Absolute Barbecues           4.850           2
# 132  AB's - Absolute Barbecues           4.825           4
# 342         Naturals Ice Cream           4.800           2
# ..                         ...             ...         ...
# 555               Jyoti Sweets           0.000           2
# 406    Bikaner Sweets & Bakers           0.000           2
# 162       Riyaz Biryani Corner           0.000           3
# 705              Golden Bakery           0.000           2
# 92               Kettle & Kegs           0.000           5
#
# [734 rows x 3 columns]
